# %% [markdown]
# # Turn TensorFlow functions into mathematical notations and diagrams

# %% [markdown]
# This is based on some helper classes I started writing,
# to help my self make less mistakes and understand the code better.
# It is still work in progress.
# I want to share the idea to see if it interests others.

# %% [markdown]
# **TLDR**: it is a bunch of helper functions that can act
# as a direct replacement of tensorflow. It renders mathematical formulas
# and output tensor dimensions. I'm looking for feedback.

# %% [markdown]
# ## Example
#
#
# There's a bunch of things I've been working on.
# In order to show them I've used the initial model creation code of
# [this tensorflow implementation of capsule nets](https://github.com/ageron/handson-ml/blob/master/extra_capsnets.ipynb).
# *Starting from **Input Images** upto **Digit Capsules**.*

# %% [markdown]
# Import the library. I'm trying to make it work as a direct replacement.

# %%
from for_beginners import tensorflow_wrapper as tf
from for_beginners.model import Model
# Out:
# <script>var __extends = (this && this.__extends) || (function () {
#     var extendStatics = Object.setPrototypeOf ||
#         ({ __proto__: [] } instanceof Array && function (d, b) { d.__proto__ = b; }) ||
#         function (d, b) { for (var p in b) if (b.hasOwnProperty(p)) d[p] = b[p]; };
#     return function (d, b) {
#         extendStatics(d, b);
#         function __() { this.constructor = d; }
#         d.prototype = b === null ? Object.create(b) : (__.prototype = b.prototype, new __());
#     };
# })();
# define("consts", ["require", "exports"], function (require, exports) {
#     "use strict";
#     Object.defineProperty(exports, "__esModule", { value: true });
#     var ELLIPSES = '…';
#     exports.ELLIPSES = ELLIPSES;
#     var CELL_SIZE = 15;
#     exports.CELL_SIZE = CELL_SIZE;
#     var BLOCK_SIZE = 16;
#     exports.BLOCK_SIZE = BLOCK_SIZE;
# });
# define("tensor", ["require", "exports"], function (require, exports) {
#     "use strict";
#     Object.defineProperty(exports, "__esModule", { value: true });
# });
# define("tensor_3d", ["require", "exports", "consts"], function (require, exports, consts_1) {
#     "use strict";
#     Object.defineProperty(exports, "__esModule", { value: true });
#     var Cell3D = /** @class */ (function () {
#         function Cell3D(x, y, z, tensor, parent) {
#             this.parent = parent;
#             this.x = x;
#             this.y = y;
#             this.z = z;
#             this.tensor = tensor;
#         }
#         Cell3D.prototype.render = function (hasFaces) {
#             this.renderCellContainer();
#             this.faces = new Array(6);
#             for (var i = 0; i < 6; ++i) {
#                 if (hasFaces && hasFaces[i] == false)
#                     continue;
#                 this.faces[i] = document.createElement("div");
#                 this.faces[i].classList.add("fbeg-face");
#                 this.faces[i].classList.add("fbeg-face-" + (i + 1));
#                 this.elem.appendChild(this.faces[i]);
#             }
#         };
#         Cell3D.prototype.renderLabel = function (face, label) {
#             this.renderCellContainer();
#             this.faces = new Array(6);
#             this.faces[face] = document.createElement("div");
#             this.faces[face].classList.add("fbeg-label");
#             this.faces[face].classList.add("fbeg-face");
#             this.faces[face].classList.add("fbeg-face-" + (face + 1));
#             this.faces[face].textContent = label;
#             this.elem.appendChild(this.faces[face]);
#         };
#         Cell3D.prototype.renderCellContainer = function () {
#             this.elem = document.createElement("div");
#             this.elem.classList.add("fbeg-cell");
#             this.parent.appendChild(this.elem);
#             var z = consts_1.BLOCK_SIZE - this.z;
#             var x = consts_1.BLOCK_SIZE - this.tensor.X + this.x + 1;
#             var y = this.tensor.Y - this.y;
#             this.elem.style.top = z * consts_1.CELL_SIZE + "px";
#             this.elem.style.left = x * consts_1.CELL_SIZE + "px";
#             this.elem.style.transform = "translate3d(0px, 0px, " + y * consts_1.CELL_SIZE + "px)";
#         };
#         return Cell3D;
#     }());
#     var Tensor3D = /** @class */ (function () {
#         function Tensor3D(x, y, z, parent) {
#             this.parent = parent;
#             this.x = x;
#             this.y = y;
#             this.z = z;
#         }
#         Object.defineProperty(Tensor3D.prototype, "X", {
#             get: function () {
#                 return Math.min(this.x, 7);
#             },
#             enumerable: true,
#             configurable: true
#         });
#         Object.defineProperty(Tensor3D.prototype, "Y", {
#             get: function () {
#                 return Math.min(this.y, 7);
#             },
#             enumerable: true,
#             configurable: true
#         });
#         Object.defineProperty(Tensor3D.prototype, "Z", {
#             get: function () {
#                 return Math.min(this.z, 7);
#             },
#             enumerable: true,
#             configurable: true
#         });
#         Tensor3D.prototype.render = function () {
#             this.renderFrame();
#             this.renderCells();
#             this.renderXLabels();
#             this.renderYLabels();
#             this.renderZLabels();
#         };
#         Tensor3D.prototype.renderFrame = function () {
#             this.container = document.createElement("div");
#             this.container.classList.add("fbeg-tensor-container");
#             this.parent.appendChild(this.container);
#             this.content = document.createElement("div");
#             this.content.classList.add("fbeg-3d-content");
#             this.container.appendChild(this.content);
#             this.elem = document.createElement("div");
#             this.elem.classList.add("fbeg-3d");
#             this.content.appendChild(this.elem);
#             var l = (1 + Math.cos(Math.PI / 5.5) * this.X) * consts_1.CELL_SIZE;
#             var L = (1 + Math.cos(Math.PI / 5.5) * 7) * consts_1.CELL_SIZE;
#             var r = (0 + Math.cos(Math.PI / 6) * this.Z) * consts_1.CELL_SIZE;
#             var R = (0 + Math.cos(Math.PI / 6) * 7) * consts_1.CELL_SIZE;
#             var b = consts_1.CELL_SIZE;
#             var t = (1 + this.Y + (Math.sin(Math.PI / 6) + Math.sin(Math.PI / 48)) * (this.Z + this.X) / 2) * consts_1.CELL_SIZE;
#             var T = (1 + 7 + (Math.sin(Math.PI / 6) + Math.sin(Math.PI / 48)) * 7) * consts_1.CELL_SIZE;
#             this.container.style.width = l + r + "px";
#             this.container.style.height = t + b + "px";
#             this.content.style.left = l - L + "px";
#             this.content.style.top = t - T + "px";
#             //this.elem.style.width = `${200}px`
#             //this.elem.style.height = `${200}px`
#         };
#         Tensor3D.prototype.renderCells = function () {
#             var faces = new Array(6);
#             for (var x = 0; x < this.X; ++x) {
#                 for (var y = 0; y < this.Y; ++y) {
#                     for (var z = 0; z < this.Z; ++z) {
#                         faces[0] = y == 0; //top
#                         faces[1] = z == this.Z - 1; //back
#                         faces[2] = z == 0; //front
#                         faces[3] = x == 0; //side behind
#                         faces[4] = x == this.X - 1; //side front
#                         faces[5] = y == this.Y - 1; // bottom
#                         if (this.x > this.X) {
#                             if (x == this.X - 3)
#                                 faces[4] = true;
#                             if (x == this.X - 2)
#                                 continue;
#                             if (x == this.X - 1)
#                                 faces[3] = true;
#                         }
#                         if (this.y > this.Y) {
#                             if (y == this.Y - 3)
#                                 faces[5] = true;
#                             if (y == this.Y - 2)
#                                 continue;
#                             if (y == this.Y - 1)
#                                 faces[0] = true;
#                         }
#                         if (this.z > this.Z) {
#                             if (z == this.Z - 3)
#                                 faces[1] = true;
#                             if (z == this.Z - 2)
#                                 continue;
#                             if (z == this.Z - 1)
#                                 faces[2] = true;
#                         }
#                         var has = false;
#                         for (var i = 0; i < 6; ++i) {
#                             if (faces[i])
#                                 has = true;
#                         }
#                         if (!has)
#                             continue;
#                         var cell = new Cell3D(x, y, z, this, this.elem);
#                         cell.render(faces);
#                     }
#                 }
#             }
#         };
#         Tensor3D.prototype.renderXLabels = function () {
#             for (var x = 0; x < this.X; ++x) {
#                 var label = "" + x;
#                 if (this.x > this.X) {
# <style>/** PLANE **/
# .fbeg-container * {
#   margin: 0 0;
#   padding: 0 0;
#   font-size: 0;
#   font-family: 'Arial', sans-serif;
#   user-select: none;
#   -webkit-user-select: none;
#   -moz-user-select: none;
#   border: none;
#   outline: none; }
#
# .fbeg-container .fbeg-tensor-container {
#   position: relative;
#   width: 200px;
#   height: 200px;
#   overflow: hidden; }
#   .fbeg-container .fbeg-tensor-container .fbeg-2d-content {
#     position: absolute;
#     width: 200px;
#     height: 200px;
#     left: 15px;
#     top: 15px; }
#     .fbeg-container .fbeg-tensor-container .fbeg-2d-content .fbeg-2d {
#       width: 240px;
#       height: 240px;
#       position: absolute; }
#       .fbeg-container .fbeg-tensor-container .fbeg-2d-content .fbeg-2d .fbeg-cell {
#         position: relative; }
#         .fbeg-container .fbeg-tensor-container .fbeg-2d-content .fbeg-2d .fbeg-cell .fbeg-face {
#           box-sizing: border-box;
#           position: absolute;
#           width: 15px;
#           height: 15px;
#           background-color: rgba(50, 50, 50, 0.7);
#           opacity: 1;
#           border-left: solid 1px #666;
#           border-top: solid 1px #666;
#           z-index: 2; }
#         .fbeg-container .fbeg-tensor-container .fbeg-2d-content .fbeg-2d .fbeg-cell .fbeg-face-right {
#           border-right: solid 1px #666; }
#         .fbeg-container .fbeg-tensor-container .fbeg-2d-content .fbeg-2d .fbeg-cell .fbeg-face-bottom {
#           border-bottom: solid 1px #666; }
#         .fbeg-container .fbeg-tensor-container .fbeg-2d-content .fbeg-2d .fbeg-cell .fbeg-label.fbeg-face {
#           background-color: transparent;
#           border: none;
#           color: #ccc;
#           font-family: 'Gill Sans', 'Gill Sans MT', Calibri, 'Trebuchet MS', sans-serif;
#           font-size: 8px;
#           text-align: center;
#           line-height: 15px; }
#   .fbeg-container .fbeg-tensor-container .fbeg-3d-content {
#     position: absolute;
#     width: 200px;
#     height: 200px;
#     perspective-origin: 50% 300px;
#     perspective: 1200px;
#     overflow: hidden; }
#     .fbeg-container .fbeg-tensor-container .fbeg-3d-content .fbeg-3d {
#       left: -20px;
#       transform: rotateX(60deg) rotateY(0deg) rotateZ(45deg);
#       width: 240px;
#       height: 240px;
#       transform-style: preserve-3d;
#       transform-origin: 50% 50%;
#       position: absolute;
#       /** CUBE **/ }
#       .fbeg-container .fbeg-tensor-container .fbeg-3d-content .fbeg-3d .fbeg-cell {
#         position: relative;
#         transform-style: preserve-3d; }
#         .fbeg-container .fbeg-tensor-container .fbeg-3d-content .fbeg-3d .fbeg-cell .fbeg-face {
#           box-sizing: border-box;
#           position: absolute;
#           width: 15px;
#           height: 15px;
#           background-color: rgba(50, 50, 50, 0.7);
#           transform-origin: 50% 50%;
#           opacity: 1;
#           z-index: 2; }
#         .fbeg-container .fbeg-tensor-container .fbeg-3d-content .fbeg-3d .fbeg-cell .fbeg-label.fbeg-face {
#           background-color: transparent;
#           border: none;
#           color: #ccc;
#           font-family: 'Gill Sans', 'Gill Sans MT', Calibri, 'Trebuchet MS', sans-serif;
#           font-size: 8px;
#           text-align: center;
#           line-height: 15px; }
#         .fbeg-container .fbeg-tensor-container .fbeg-3d-content .fbeg-3d .fbeg-cell .fbeg-face-1 {
#           background-color: rgba(70, 70, 70, 0.7);
#           border-left: solid 1px #666;
#           border-bottom: solid 1px #666;
#           transform: translate3d(0, 0, 15px); }
#         .fbeg-container .fbeg-tensor-container .fbeg-3d-content .fbeg-3d .fbeg-cell .fbeg-face-2 {
#           border-left: solid 1px #666;
#           border-bottom: solid 1px #666;
#           transform-origin: 0% 50%;
#           transform: rotateX(90deg) translate3d(0, 7.5px, 7.5px); }
#         .fbeg-container .fbeg-tensor-container .fbeg-3d-content .fbeg-3d .fbeg-cell .fbeg-face-3 {
#           border-left: solid 1px #666;
#           border-bottom: solid 1px #666;
#           transform-origin: 50% 50%;
#           transform: rotateX(-90deg) translate3d(0, -7.5px, 7.5px); }
#         .fbeg-container .fbeg-tensor-container .fbeg-3d-content .fbeg-3d .fbeg-cell .fbeg-face-4 {
#           border-right: solid 1px #666;
#           border-top: solid 1px #666;
#           transform-origin: 50% 0%;
#           transform: rotateY(90deg) translate3d(-7.5px, 0px, -7.5px); }
#         .fbeg-container .fbeg-tensor-container .fbeg-3d-content .fbeg-3d .fbeg-cell .fbeg-face-5 {
#           background-color: rgba(30, 30, 30, 0.7);
#           border-left: solid 1px #666;
#           border-top: solid 1px #666;
#           transform-origin: 50% 50%;
#           transform: rotateX(-90deg) rotateY(90deg) translate3d(0px, -7.5px, 7.5px); }
#         .fbeg-container .fbeg-tensor-container .fbeg-3d-content .fbeg-3d .fbeg-cell .fbeg-face-6 {
#           border-right: solid 1px #666;
#           border-top: solid 1px #666; }
# </style>

# %% [markdown]
# All the operations and variables are assigned to a model.
# This takes care of variable names, so that you don't have
# to explicitly specify `name=`.

# %%
model = Model()

# %% [markdown]
# Create a place holder just like you do with [TensorFlow](https://www.tensorflow.org),
# and assign it to `model`. The library will set the tensorflow name, and output a nice
# 3D diagram showing the dimensions of the placeholder.

# %%
model.X = tf.placeholder(shape=[None, 28, 28, 1], dtype=tf.float32)
# Out:
# \begin{align}
# X
# \end{align}
# <div id="vxldcihont"></div><script>require(["main"], function(main) { main.renderTensor("vxldcihont", [28, 28, 1]); });</script>

# %% [markdown]
# The dimensions of the tensor is visualized in 3D.
# This is more convenient than having to write an extra line
# to output the shape of $X$.
# I'm not sure if this is the best way to visualize;
# I have discussed some other ideas later.
#
# Also notice that we didn't pass the variable name as an argument;
# it was extracted from the assigned property name.
# The cost of this is that we have to use a `model` to store all
# variables and operations.

# %%
caps1_n_maps = 32
caps1_n_caps = caps1_n_maps * 6 * 6  # 1152 primary capsules
caps1_n_dims = 8

# %%
conv1_params = {
    "filters": 256,
    "kernel_size": 9,
    "strides": 1,
    "padding": "valid",
    "activation": tf.nn.relu,
}

conv2_params = {
    "filters": caps1_n_maps * caps1_n_dims, # 256 convolutional filters
    "kernel_size": 9,
    "strides": 2,
    "padding": "valid",
    "activation": tf.nn.relu
}

# %% [markdown]
# You can add `conv2d` layers similarly.

# %%
model.conv1 = tf.layers.conv2d(model.X, **conv1_params)
model.conv2 = tf.layers.conv2d(model.conv1, **conv2_params)

# %% [markdown]
# Above diagram shows that there are `6x6` feature maps of `256` channels after the second convolution.
# I'm planning to indicate the *strides*, *kernel size* and *padding* on the 2-D diagram.

# %%
model.caps1_raw = tf.reshape(model.conv2, [-1, caps1_n_caps, caps1_n_dims])

# %% [markdown]
# Here's a function definition.
# You can add a naming scope,
# so that it will not render internal operations.

# %%
def squash(s, axis=-1, epsilon=tf.constant(1e-7), name=None):
    model.epsilon = epsilon
    if name is None:
        name = 'squash'
    model.add_scope(name)
    model.squared_norm = tf.reduce_sum(tf.square(s), axis=axis,
                                 keep_dims=True)
    model.safe_norm = tf.sqrt(tf.add(model.squared_norm, epsilon))
    model.squash_factor = tf.divide(model.squared_norm, tf.add(1., model.squared_norm))
    model.unit_vector = tf.divide(s, model.safe_norm)
    model.squashed = tf.multiply(model.squash_factor, model.unit_vector)

    model.remove_scope() # Need to implement with mode.scope ....
    
    return model.squashed

# %% [markdown]
# Call to the function will render the full formula and output tensor dimensions.

# %%
model.caps1_output = squash(model.caps1_raw, name="caps1_squash")

# %% [markdown]
# This helps you verify the formulas when coding.
# It help readers quickly understand whats going on,
# without having to look back at the function definition.
#
# Notice that, tries to convert the variable names into mathematical symbols;
# e.g. `epsilon` -> $\epsilon$

# %% [markdown]
# ## Why?
#
# This was developed to make machine learning code easier to understand,
# at the time of writing as well as for readers.
# I have only tried this on small networks (mostly based on tutorials).
# So far I've found it helpful.
#
# I feel it's helpful for beginners than for experts,
# who get confused on the detailed workings of the functions.
# This is espcially true for me because I only work on tensorflow
# on and off, and I forget all the details.
#
# It is also useful when writing notebooks intended for others to read (like tutorials).

# %% [markdown]
# ## What's next?
#
# The above example shows most of the things I've implemented so far.
# It's just a couple of hunderd lines of python and javascript I've written on free time.
# I am planning to cleanup the code and host it on github.
# Right now the code is messy, and needs to be fixed almost everytime I use it.
#
# ### Cover more tensorflow operations
#
# Current implementaion is only for a few common tensorflow functions.
#
# Also, the library doesn't do operator overloading which is really important.
# That is, we should be able to write `X / Y`
# instead of `tf.divide(X, Y)`
#
# ### Diagrams to how operations work
#
# We need to include more details in diagrams to explain complex operation.
# For instance, we can *indicate padding, strides and kernal size
# in the diagram for convolution operation*.
# We can do similar diagrams for tensor transformations.
#
# Also, the current 2-D and 3-D tensor diagrams might
# not be the best in all situations.
# It sometimes makes more sense not to show individual cells,
# butto show the sizes of the dimensions.
#
# Why I decided to show individual cells is with the intention of
# adding details like highlighted cells, kernels, etc on the same diagram.
#
# ![matrix](http://blog.varunajayasiri.com/ml/tf_for_beginners/matrix.png)
#
# It's sometimes important to show higher dimensianality,
# especially for operations like reshaping and tiling.
#
# ![tiling](http://blog.varunajayasiri.com/ml/tf_for_beginners/tile.png)
#
# And, on some occasions,
# it may be just enough to show the shape of the tensor in text;
# e.g. `([?, 10, 50, 20, 10])`.
#
# ### Function Wrappers
#
# For example, we can wrap the function `squash`.
#
#     wrap(tensor(['N', 'H', 'W'])
#     def squash(s, axis=-1, epsilon=Noob(tf.constant, 1e-7), name=None):
#         ...
#
# And it can display the full formula for the function and the output tensor dimensions.
# This will help us test functions before calling them, and help readers get an overview
# of the function without reading the internals.
#
# ### Please give your feedback. Find me on twitter [@vpj](https://twitter.com/vpj).
